# %%
import pandas as pd

# %%
ds = pd.read_csv("./Train_data.csv")
ds.drop(columns=[
"service",
"src_bytes", "dst_bytes",
"land" ,
"urgent",
"hot",
"num_failed_logins",
"logged_in",
"root_shell",
"su_attempted",
"num_root",
"num_file_creations",
"num_shells",
"num_access_files",
"num_outbound_cmds",
"is_host_login",
"is_guest_login",
"srv_count",
"diff_srv_rate",
"dst_host_same_src_port_rate",
"dst_host_srv_diff_host_rate",
"dst_host_rerror_rate",
"dst_host_srv_rerror_rate"],inplace=True)

ds = pd.get_dummies(ds,columns=['protocol_type','flag'],drop_first=True)
ds.head()
# Out:
#    duration  wrong_fragment  num_compromised  count  serror_rate  \
# 0         0               0                0      2          0.0
# 1         0               0                0     13          0.0
# 2         0               0                0    123          1.0
# 3         0               0                0      5          0.2
# 4         0               0                0     30          0.0
#
#    srv_serror_rate  rerror_rate  srv_rerror_rate  same_srv_rate  \
# 0              0.0          0.0              0.0           1.00
# 1              0.0          0.0              0.0           0.08
# 2              1.0          0.0              0.0           0.05
# 3              0.2          0.0              0.0           1.00
# 4              0.0          0.0              0.0           1.00
#
#    srv_diff_host_rate  ...  flag_REJ  flag_RSTO  flag_RSTOS0  flag_RSTR  \
# 0                0.00  ...     False      False        False      False
# 1                0.00  ...     False      False        False      False
# 2                0.00  ...     False      False        False      False
# 3                0.00  ...     False      False        False      False
# 4                0.09  ...     False      False        False      False
#
#    flag_S0  flag_S1 flag_S2  flag_S3  flag_SF  flag_SH
# 0    False    False   False    False     True    False
# 1    False    False   False    False     True    False
# 2     True    False   False    False    False    False
# 3    False    False   False    False     True    False
# 4    False    False   False    False     True    False
#
# [5 rows x 29 columns]

# %%
y = ds['class'].values
ds.drop(columns=['class'],inplace=True)
x = ds[:].values

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report
import joblib

# %%
decision_tree_model = DecisionTreeClassifier(random_state=0)
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)
decision_tree_model.fit(X_train,y_train)
joblib.dump(decision_tree_model,"decision_tree_model.pk1")
y_pred = decision_tree_model.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9867037110537805
# Classification Report:
#                precision    recall  f1-score   support
#
#      anomaly       0.98      0.99      0.99      2326
#       normal       0.99      0.99      0.99      2713
#
#     accuracy                           0.99      5039
#    macro avg       0.99      0.99      0.99      5039
# weighted avg       0.99      0.99      0.99      5039

# %%
testing = pd.read_csv("./Test_data.csv")
testing.drop(columns=[
"service",
"src_bytes", "dst_bytes",
"land" ,
"urgent",
"hot",
"num_failed_logins",
"logged_in",
"root_shell",
"su_attempted",
"num_root",
"num_file_creations",
"num_shells",
"num_access_files",
"num_outbound_cmds",
"is_host_login",
"is_guest_login",
"srv_count",
"diff_srv_rate",
"dst_host_same_src_port_rate",
"dst_host_srv_diff_host_rate",
"dst_host_rerror_rate",
"dst_host_srv_rerror_rate"],inplace=True)
testing = pd.get_dummies(testing,columns=['protocol_type','flag'],drop_first=True)
testing.head()
# Out:
#    duration  wrong_fragment  num_compromised  count  serror_rate  \
# 0         0               0                0    229          0.0
# 1         0               0                0    136          0.0
# 2         2               0                0      1          0.0
# 3         0               0                0      1          0.0
# 4         1               0                0      1          0.0
#
#    srv_serror_rate  rerror_rate  srv_rerror_rate  same_srv_rate  \
# 0             0.00          1.0              1.0           0.04
# 1             0.00          1.0              1.0           0.01
# 2             0.00          0.0              0.0           1.00
# 3             0.00          0.0              0.0           1.00
# 4             0.12          1.0              0.5           1.00
#
#    srv_diff_host_rate  ...  flag_REJ  flag_RSTO  flag_RSTOS0  flag_RSTR  \
# 0                0.00  ...      True      False        False      False
# 1                0.00  ...      True      False        False      False
# 2                0.00  ...     False      False        False      False
# 3                1.00  ...     False      False        False      False
# 4                0.75  ...     False       True        False      False
#
#    flag_S0  flag_S1  flag_S2  flag_S3  flag_SF  flag_SH
# 0    False    False    False    False    False    False
# 1    False    False    False    False    False    False
# 2    False    False    False    False     True    False
# 3    False    False    False    False     True    False
# 4    False    False    False    False    False    False
#
# [5 rows x 28 columns]

# %%
x = testing.values

# %%
y_pred = decision_tree_model.predict(x)
testing['class'] = y_pred
testing.head()
# Out:
#    duration  wrong_fragment  num_compromised  count  serror_rate  \
# 0         0               0                0    229          0.0
# 1         0               0                0    136          0.0
# 2         2               0                0      1          0.0
# 3         0               0                0      1          0.0
# 4         1               0                0      1          0.0
#
#    srv_serror_rate  rerror_rate  srv_rerror_rate  same_srv_rate  \
# 0             0.00          1.0              1.0           0.04
# 1             0.00          1.0              1.0           0.01
# 2             0.00          0.0              0.0           1.00
# 3             0.00          0.0              0.0           1.00
# 4             0.12          1.0              0.5           1.00
#
#    srv_diff_host_rate  ...  flag_RSTO  flag_RSTOS0  flag_RSTR  flag_S0  \
# 0                0.00  ...      False        False      False    False
# 1                0.00  ...      False        False      False    False
# 2                0.00  ...      False        False      False    False
# 3                1.00  ...      False        False      False    False
# 4                0.75  ...       True        False      False    False
#
#    flag_S1  flag_S2  flag_S3  flag_SF  flag_SH    class
# 0    False    False    False    False    False  anomaly
# 1    False    False    False    False    False  anomaly
# 2    False    False    False     True    False   normal
# 3    False    False    False     True    False  anomaly
# 4    False    False    False    False    False   normal
#
# [5 rows x 29 columns]
